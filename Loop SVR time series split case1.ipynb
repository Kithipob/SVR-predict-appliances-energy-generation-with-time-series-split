# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error,r2_score

# %%
df=pd.read_csv('energydata_complete.csv')
df
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
df['date'] = pd.to_datetime(df['date'])
df= df.sort_values(['date'])
df.set_index('date', inplace=True)
df
# Out:
#                      Appliances  lights         T1       RH_1         T2  \
# date
# 2016-01-11 17:00:00          60      30  19.890000  47.596667  19.200000
# 2016-01-11 17:10:00          60      30  19.890000  46.693333  19.200000
# 2016-01-11 17:20:00          50      30  19.890000  46.300000  19.200000
# 2016-01-11 17:30:00          50      40  19.890000  46.066667  19.200000
# 2016-01-11 17:40:00          60      40  19.890000  46.333333  19.200000
# ...                         ...     ...        ...        ...        ...
# 2016-05-27 17:20:00         100       0  25.566667  46.560000  25.890000
# 2016-05-27 17:30:00          90       0  25.500000  46.500000  25.754000
# 2016-05-27 17:40:00         270      10  25.500000  46.596667  25.628571
# 2016-05-27 17:50:00         420      10  25.500000  46.990000  25.414000
# 2016-05-27 18:00:00         430      10  25.500000  46.600000  25.264286
#
#                           RH_2         T3       RH_3         T4       RH_4  \
# date
# ...

# %%
df.drop(['rv1', 'rv2'],axis=1,inplace=True)

# %%
df.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
df.columns=['Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4',
       'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9',
       'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed', 'Visibility',
       'Tdewpoint']
df
# Out:
#                      Appliances  lights         T1       RH_1         T2  \
# date
# 2016-01-11 17:00:00          60      30  19.890000  47.596667  19.200000
# 2016-01-11 17:10:00          60      30  19.890000  46.693333  19.200000
# 2016-01-11 17:20:00          50      30  19.890000  46.300000  19.200000
# 2016-01-11 17:30:00          50      40  19.890000  46.066667  19.200000
# 2016-01-11 17:40:00          60      40  19.890000  46.333333  19.200000
# ...                         ...     ...        ...        ...        ...
# 2016-05-27 17:20:00         100       0  25.566667  46.560000  25.890000
# 2016-05-27 17:30:00          90       0  25.500000  46.500000  25.754000
# 2016-05-27 17:40:00         270      10  25.500000  46.596667  25.628571
# 2016-05-27 17:50:00         420      10  25.500000  46.990000  25.414000
# 2016-05-27 18:00:00         430      10  25.500000  46.600000  25.264286
#
#                           RH_2         T3       RH_3         T4       RH_4  \
# date
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
values = df.values
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
scaled
# Out:
# array([[0.04672897, 0.42857143, 0.32734952, ..., 0.5       , 0.95384615,
#         0.53846154],
#        [0.04672897, 0.42857143, 0.32734952, ..., 0.47619048, 0.89487179,
#         0.53393665],
#        [0.03738318, 0.42857143, 0.32734952, ..., 0.45238095, 0.83589744,
#         0.52941176],
#        ...,
#        [0.24299065, 0.14285714, 0.91974657, ..., 0.26190476, 0.37435897,
#         0.89894419],
#        [0.38317757, 0.14285714, 0.91974657, ..., 0.27380952, 0.38717949,
#         0.8974359 ],
#        [0.39252336, 0.14285714, 0.91974657, ..., 0.28571429, 0.4       ,
#         0.8959276 ]])

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):
    
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
n_out=1
n_in=10
reframed = series_to_supervised(scaled, n_in, n_out,feat_name=df.columns)
reframed.drop(['lights(t)', 'T1(t)', 'RH_1(t)', 'T2(t)',
       'RH_2(t)', 'T3(t)', 'RH_3(t)', 'T4(t)', 'RH_4(t)', 'T5(t)', 'RH_5(t)',
       'T6(t)', 'RH_6(t)', 'T7(t)', 'RH_7(t)', 'T8(t)', 'RH_8(t)', 'T9(t)',
       'RH_9(t)', 'T_out(t)', 'Press_mm_hg(t)', 'RH_out(t)', 'Windspeed(t)',
       'Visibility(t)', 'Tdewpoint(t)'],axis=1,inplace=True)
reframed
# Out:
#        Appliances(t-10)  lights(t-10)  T1(t-10)  RH_1(t-10)  T2(t-10)  \
# 10             0.046729      0.428571  0.327350    0.566187  0.225345
# 11             0.046729      0.428571  0.327350    0.541326  0.225345
# 12             0.037383      0.428571  0.327350    0.530502  0.225345
# 13             0.037383      0.571429  0.327350    0.524080  0.225345
# 14             0.046729      0.571429  0.327350    0.531419  0.225345
# ...                 ...           ...       ...         ...       ...
# 19730          0.056075      0.000000  0.919747    0.509105  0.726920
# 19731          0.084112      0.000000  0.919747    0.512155  0.725466
# 19732          0.084112      0.000000  0.919747    0.514815  0.719651
# 19733          0.074766      0.000000  0.919747    0.516466  0.719651
# 19734          0.084112      0.000000  0.919747    0.520411  0.719651
#
#        RH_2(t-10)  T3(t-10)  RH_3(t-10)  T4(t-10)  RH_4(t-10)  ...  RH_8(t-1)  \
# ...

# %%
split_train =int(reframed.shape[0]*0.6)
split_test = int(reframed.shape[0]*(0.6+0.2))
    
train = reframed[:split_train]
test = reframed[split_train:split_test]
forecast = reframed[split_test:]

# %%
train.shape
# Out:
# (11835, 261)

# %%
from sklearn.model_selection import TimeSeriesSplit
cv = TimeSeriesSplit(max_train_size=None, n_splits=3)
i=0
for train_val, test_val in cv.split(train):
    i=i+1
    print ("No of observations under train%s=%s" % (i, len(train_val)))
    print ("No of observations under val%s=%s" % (i, len(test_val)))
# Out:
# No of observations under train1=2961
# No of observations under val1=2958
# No of observations under train2=5919
# No of observations under val2=2958
# No of observations under train3=8877
# No of observations under val3=2958

# %%
train1, val1 = train[:2961], train[2961:5919]
train2, val2 = train[:5919], train[5919:8877]
train3, val3 = train[:8877], train[8877:8877+2958]

# %%
cv_train=[train1,train2,train3]
cv_test=[val1,val2,val3]

# %%
cv_xtrain=[]
cv_ytrain=[]
cv_xtest=[]
cv_ytest=[]
for i in range(3):
    train_X, train_y = cv_train[i].values[:, :-1], cv_train[i].values[:, -1:]
    cv_xtrain.append(train_X)
    cv_ytrain.append(train_y)
    test_X, test_y = cv_test[i].values[:, :-1], cv_test[i].values[:, -1:]
    cv_xtest.append(test_X)
    cv_ytest.append(test_y)

# %%
for i in range(3):
  cv_ytrain[i]=cv_ytrain[i].reshape(cv_ytrain[i].shape[0],)

# %%
cv_xtrain[0].shape
# Out:
# (2961, 260)

# %%
cv_ytrain[0].shape
# Out:
# (2961,)

# %%
train_X, train_y = train.values[:, :-1], train.values[:, -1:]
test_X, test_y = test.values[:, :-1], test.values[:, -1:]
forecast_X,forecast_y = forecast.values[:, :-1], forecast.values[:, -1:]

# %%
x_train=[cv_xtrain[0],cv_xtrain[1],cv_xtrain[2],train_X]
y_train=[cv_ytrain[0],cv_ytrain[1],cv_ytrain[2],train_y]
x_test=[cv_xtest[0],cv_xtest[1],cv_xtest[2],test_X]
y_test=[cv_ytest[0],cv_ytest[1],cv_ytest[2],test_y]

# %% [markdown]
# # Train Model

# %%
for i in range(len(x_train)):
    svr = SVR(kernel='linear',C=100)
    svr.fit(x_train[i],y_train[i])
    if i == len(x_train):
        break
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %% [markdown]
# # Forecast

# %%
yhat = svr.predict(forecast_X)

# %%
yhat.shape
# Out:
# (3945,)

# %%
td=[]
for i in range(26):
    ts=forecast_X[::,(i+1)]
    ts=ts.reshape(len(forecast_X),1)
    td.append(ts)

# %%
yhat=yhat.reshape(yhat.shape[0],1)
forecast_y=forecast_y.reshape(forecast_y.shape[0],1)

# %%
inv_yhat=np.hstack((yhat,td[0],td[1],td[2],td[3],td[4],td[5],td[6],td[7],td[8],td[9],td[10],td[11],td[12],td[13],td[14],td[15],td[16],td[17],td[18],td[19],td[20],td[21],td[22],td[23],td[24]))
inv_yhat = pd.DataFrame(inv_yhat,columns=df.columns)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat= inv_yhat[::,0] 
inv_yhat
# Out:
# array([427.83575595, 208.89578924, 294.14222256, ..., 134.32446478,
#        277.38327125, 296.3023237 ])

# %%
inv_yforecast=np.hstack((forecast_y,td[0],td[1],td[2],td[3],td[4],td[5],td[6],td[7],td[8],td[9],td[10],td[11],td[12],td[13],td[14],td[15],td[16],td[17],td[18],td[19],td[20],td[21],td[22],td[23],td[24]))
inv_yforecast = pd.DataFrame(inv_yforecast,columns=df.columns)
inv_yforecast = scaler.inverse_transform(inv_yforecast)
inv_yforecast = inv_yforecast[::,0] 
inv_yforecast
# Out:
# array([320., 310., 260., ..., 270., 420., 430.])

# %% [markdown]
# # Error

# %%
rmse = np.sqrt(mean_squared_error(inv_yforecast, inv_yhat))
r2=r2_score(inv_yforecast, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test R2-score: %.3f' % r2)
# Out:
# Test RMSE: 82.145
# Test R2-score: 0.178

# %% [markdown]
# # Plot Forecast

# %%
td = []
for i in range(26):
    ts = test_X[::,(i+1)]
    ts = ts.reshape(len(test_X),1)
    td.append(ts)
inv_tytest=np.hstack((test_y,td[0],td[1],td[2],td[3],td[4],td[5],td[6],td[7],td[8],td[9],td[10],td[11],td[12],td[13],td[14],td[15],td[16],td[17],td[18],td[19],td[20],td[21],td[22],td[23],td[24]))
inv_tytest = pd.DataFrame(inv_tytest,columns=df.columns)
inv_tytest = scaler.inverse_transform(inv_tytest)
inv_tytest = inv_tytest[::,0]

# %%
td=[]
for i in range(26):
    ts=train_X[::,(i+1)]
    ts=ts.reshape(len(train_X),1)
    td.append(ts)
inv_ytrain=np.hstack((train_y,td[0],td[1],td[2],td[3],td[4],td[5],td[6],td[7],td[8],td[9],td[10],td[11],td[12],td[13],td[14],td[15],td[16],td[17],td[18],td[19],td[20],td[21],td[22],td[23],td[24]))
inv_ytrain = pd.DataFrame(inv_ytrain,columns=df.columns)
inv_ytrain = scaler.inverse_transform(inv_ytrain)
inv_ytrain= inv_ytrain[::,0]

# %%
plt.figure(figsize=(16,8))
plt.title('Appliances(Wh)')

plt.plot(train.index,inv_ytrain,label='train',color='g')
plt.plot(test.index,inv_tytest ,color='b',label='test')
plt.plot(forecast.index,inv_yforecast,color='y',label='forecast actual')
plt.plot(forecast.index,inv_yhat,label='forecast (SVR)',color='r')
plt.legend(fontsize = 'large')
plt.show()
